# %%
import pyspark.sql.functions as F
from pyspark.sql.window import Window

data = [("Anderson","Sales","NY",90000),
    ("Kenedy","Sales","CA",86000),
    ("Kenny","Sales","CA",86000),
    ("Billy","Sales","NY",81000),
    ("Andy","Finance","CA",90000),
    ("Mary","Finance","NY",99000),
    ("Eduardo","Finance","NY",83000),
    ("Mendes","Finance","CA",79000),
    ("Keyth","Marketing","CA",80000),
    ("Truman","Marketing","NY",91000)
  ]

schema = ["name","dep_name","state","salary"]
spark.createDataFrame(data=data, schema = schema).createOrReplaceTempView("tbl_window")

# %%
# %sql
SELECT * FROM tbl_window
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>dep_name</th><th>state</th><th>salary</th></tr></thead><tbody><tr><td>Anderson</td><td>Sales</td><td>NY</td><td>90000</td></tr><tr><td>Kenedy</td><td>Sales</td><td>CA</td><td>86000</td></tr><tr><td>Kenny</td><td>Sales</td><td>CA</td><td>86000</td></tr><tr><td>Billy</td><td>Sales</td><td>NY</td><td>81000</td></tr><tr><td>Andy</td><td>Finance</td><td>CA</td><td>90000</td></tr><tr><td>Mary</td><td>Finance</td><td>NY</td><td>99000</td></tr><tr><td>Eduardo</td><td>Finance</td><td>NY</td><td>83000</td></tr><tr><td>Mendes</td><td>Finance</td><td>CA</td><td>79000</td></tr><tr><td>Keyth</td><td>Marketing</td><td>CA</td><td>80000</td></tr><tr><td>Truman</td><td>Marketing</td><td>NY</td><td>91000</td></tr></tbody></table></div>

# %%
# %sql
SELECT name, dep_name, salary, RANK() OVER (PARTITION BY dep_name ORDER BY salary) AS rank FROM tbl_window
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>dep_name</th><th>salary</th><th>rank</th></tr></thead><tbody><tr><td>Mendes</td><td>Finance</td><td>79000</td><td>1</td></tr><tr><td>Eduardo</td><td>Finance</td><td>83000</td><td>2</td></tr><tr><td>Andy</td><td>Finance</td><td>90000</td><td>3</td></tr><tr><td>Mary</td><td>Finance</td><td>99000</td><td>4</td></tr><tr><td>Keyth</td><td>Marketing</td><td>80000</td><td>1</td></tr><tr><td>Truman</td><td>Marketing</td><td>91000</td><td>2</td></tr><tr><td>Billy</td><td>Sales</td><td>81000</td><td>1</td></tr><tr><td>Kenedy</td><td>Sales</td><td>86000</td><td>2</td></tr><tr><td>Kenny</td><td>Sales</td><td>86000</td><td>2</td></tr><tr><td>Anderson</td><td>Sales</td><td>90000</td><td>4</td></tr></tbody></table></div>

# %%
# %sql
SELECT name, dep_name, salary, DENSE_RANK() OVER (PARTITION BY dep_name ORDER BY salary ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW) AS rank FROM tbl_window
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>dep_name</th><th>salary</th><th>rank</th></tr></thead><tbody><tr><td>Mendes</td><td>Finance</td><td>79000</td><td>1</td></tr><tr><td>Eduardo</td><td>Finance</td><td>83000</td><td>2</td></tr><tr><td>Andy</td><td>Finance</td><td>90000</td><td>3</td></tr><tr><td>Mary</td><td>Finance</td><td>99000</td><td>4</td></tr><tr><td>Keyth</td><td>Marketing</td><td>80000</td><td>1</td></tr><tr><td>Truman</td><td>Marketing</td><td>91000</td><td>2</td></tr><tr><td>Billy</td><td>Sales</td><td>81000</td><td>1</td></tr><tr><td>Kenedy</td><td>Sales</td><td>86000</td><td>2</td></tr><tr><td>Kenny</td><td>Sales</td><td>86000</td><td>2</td></tr><tr><td>Anderson</td><td>Sales</td><td>90000</td><td>3</td></tr></tbody></table></div>
